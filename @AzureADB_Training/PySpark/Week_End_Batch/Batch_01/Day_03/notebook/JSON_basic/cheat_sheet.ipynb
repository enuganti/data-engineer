# %% [markdown]
# - JSON Files with **Arrays (Single-line or Multiline)**
#
#       [
#         {"id":1,"type":"login"},
#         {"id":2,"type":"logout"}
#       ]
#
# - **Correct read:**
#
#       df = spark.read \
#                 .option("multiLine", "true") \
#                 .json("/data/events/*.json")
#
#       df.show()

# %% [markdown]
# ✅ **Rule of Thumb**.
#
# - Always use `*.json` when:
#   - `Folder is shared`
#   - `Data is generated by multiple jobs`
