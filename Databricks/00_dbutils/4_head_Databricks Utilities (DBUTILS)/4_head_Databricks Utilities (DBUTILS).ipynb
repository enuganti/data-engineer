# %% [markdown]
# **dbutils.fs.head()**
#
# - The dbutils.fs.head() method in Databricks is meant to read only the **initial bytes of a file**, so it is **not ideal** for **handling large files**.
#
# - This method is usually used to **quickly preview** the **content or structure** of a file.

# %%
dbutils.fs.help('head')
# Out:
# <div class = "ansiout">/**<br /> * Returns up to the first 'maxBytes' bytes of the given file as a String encoded in UTF-8.<br /> * <br /> * Example: head("/mnt/my-folder/my-file")<br /> * <br /> * @param file FileSystem URI<br /> * @param maxBytes Maximum number of bytes to read<br /> * @return String containing contents of the file, possibly truncated to the max bytes.<br /> * @throws IllegalArgumentException if the file is actually a directory.<br /> */<br /><b>head(file: java.lang.String, maxBytes: int = 65536): java.lang.String</b></div><br />

# %% [markdown]
# #### **1) databricks-datasets**

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/content/</td><td>content/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/local_disk0/</td><td>local_disk0/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls dbfs:/FileStore/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/Question7.csv</td><td>Question7.csv</td><td>154</td><td>1721635338000</td></tr><tr><td>dbfs:/FileStore/syntax-1.png</td><td>syntax-1.png</td><td>46059</td><td>1725977759000</td></tr><tr><td>dbfs:/FileStore/syntax.png</td><td>syntax.png</td><td>60188</td><td>1725976964000</td></tr><tr><td>dbfs:/FileStore/tables/</td><td>tables/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls /databricks-datasets/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls /databricks-datasets/structured-streaming
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/structured-streaming/events/</td><td>events/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls /databricks-datasets/structured-streaming/events
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs head dbfs:/databricks-datasets/structured-streaming/events/file-0.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 65536 bytes]
# {&quot;time&quot;:1469501107,&quot;action&quot;:&quot;Open&quot;}
# {&quot;time&quot;:1469501147,&quot;action&quot;:&quot;Open&quot;}
# {&quot;time&quot;:1469501202,&quot;action&quot;:&quot;Open&quot;}
# {&quot;time&quot;:1469501219,&quot;action&quot;:&quot;Open&quot;}
# {&quot;time&quot;:1469501225,&quot;action&quot;:&quot;Open&quot;}
# {&quot;time&quot;:1469501234,&quot;action&quot;:&quot;Open&quot;}
# {&quot;time&quot;:1469501245,&quot;action&quot;:&quot;Open&quot;}
# {&quot;time&quot;:1469501246,&quot;action&quot;:&quot;Open&quot;}
# ...

# %%
# %fs ls /FileStore/tables/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ### **2) Format: csv**

# %% [markdown]
# **Ex 01: bikeSharing**
#
#      dbutils.fs.head("dbfs:/databricks-datasets/bikeSharing/data-001/day.csv")
#      dbutils.fs.head("dbfs:/databricks-datasets/bikeSharing/data-001/day.csv", 1000)
#      %fs head dbfs:/databricks-datasets/bikeSharing/data-001/day.csv

# %%
# %fs ls dbfs:/databricks-datasets/bikeSharing/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/bikeSharing/README.md</td><td>README.md</td><td>5016</td><td>1454554606000</td></tr><tr><td>dbfs:/databricks-datasets/bikeSharing/data-001/</td><td>data-001/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls dbfs:/databricks-datasets/bikeSharing/data-001/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/bikeSharing/data-001/day.csv</td><td>day.csv</td><td>57569</td><td>1454547079000</td></tr><tr><td>dbfs:/databricks-datasets/bikeSharing/data-001/hour.csv</td><td>hour.csv</td><td>1156736</td><td>1454547079000</td></tr></tbody></table></div>

# %% [markdown]
#      %fs head dbfs:/databricks-datasets/bikeSharing/data-001/day.csv
#                               (or)
#      dbutils.fs.head("dbfs:/databricks-datasets/bikeSharing/data-001/day.csv")

# %%
# %fs head dbfs:/databricks-datasets/bikeSharing/data-001/day.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">instant,dteday,season,yr,mnth,holiday,weekday,workingday,weathersit,temp,atemp,hum,windspeed,casual,registered,cnt
# 1,2011-01-01,1,0,1,0,6,0,2,0.344167,0.363625,0.805833,0.160446,331,654,985
# 2,2011-01-02,1,0,1,0,0,0,2,0.363478,0.353739,0.696087,0.248539,131,670,801
# 3,2011-01-03,1,0,1,0,1,1,1,0.196364,0.189405,0.437273,0.248309,120,1229,1349
# 4,2011-01-04,1,0,1,0,2,1,1,0.2,0.212122,0.590435,0.160296,108,1454,1562
# 5,2011-01-05,1,0,1,0,3,1,1,0.226957,0.22927,0.436957,0.1869,82,1518,1600
# 6,2011-01-06,1,0,1,0,4,1,1,0.204348,0.233209,0.518261,0.0895652,88,1518,1606
# ...

# %%
dbutils.fs.head("dbfs:/databricks-datasets/bikeSharing/data-001/day.csv")
# Out:
# Out[3]: 'instant,dteday,season,yr,mnth,holiday,weekday,workingday,weathersit,temp,atemp,hum,windspeed,casual,registered,cnt\r\n1,2011-01-01,1,0,1,0,6,0,2,0.344167,0.363625,0.805833,0.160446,331,654,985\r\n2,2011-01-02,1,0,1,0,0,0,2,0.363478,0.353739,0.696087,0.248539,131,670,801\r\n3,2011-01-03,1,0,1,0,1,1,1,0.196364,0.189405,0.437273,0.248309,120,1229,1349\r\n4,2011-01-04,1,0,1,0,2,1,1,0.2,0.212122,0.590435,0.160296,108,1454,1562\r\n5,2011-01-05,1,0,1,0,3,1,1,0.226957,0.22927,0.436957,0.1869,82,1518,1600\r\n6,2011-01-06,1,0,1,0,4,1,1,0.204348,0.233209,0.518261,0.0895652,88,1518,1606\r\n7,2011-01-07,1,0,1,0,5,1,2,0.196522,0.208839,0.498696,0.168726,148,1362,1510\r\n8,2011-01-08,1,0,1,0,6,0,2,0.165,0.162254,0.535833,0.266804,68,891,959\r\n9,2011-01-09,1,0,1,0,0,0,1,0.138333,0.116175,0.434167,0.36195,54,768,822\r\n10,2011-01-10,1,0,1,0,1,1,1,0.150833,0.150888,0.482917,0.223267,41,1280,1321\r\n11,2011-01-11,1,0,1,0,2,1,2,0.169091,0.191464,0.686364,0.122132,43,1220,1263\r\n12,2011-01-12,
# ...

# %% [markdown]
# - Utility can pull the **first few records** of a file using the **head** function, as shown below.
#
# - **dbutils.fs.head()** can be passed with **number of bytes** parameter to limit the data that gets printed out.
#
# - In the example below, the **first 1000 bytes** of a csv file are printed out.

# %%
dbutils.fs.head("dbfs:/databricks-datasets/bikeSharing/data-001/day.csv", 1000)
# Out:
# [Truncated to first 1000 bytes]
# ...

# %%
# %fs head dbfs:/databricks-datasets/bikeSharing/data-001/day.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">instant,dteday,season,yr,mnth,holiday,weekday,workingday,weathersit,temp,atemp,hum,windspeed,casual,registered,cnt
# 1,2011-01-01,1,0,1,0,6,0,2,0.344167,0.363625,0.805833,0.160446,331,654,985
# 2,2011-01-02,1,0,1,0,0,0,2,0.363478,0.353739,0.696087,0.248539,131,670,801
# 3,2011-01-03,1,0,1,0,1,1,1,0.196364,0.189405,0.437273,0.248309,120,1229,1349
# 4,2011-01-04,1,0,1,0,2,1,1,0.2,0.212122,0.590435,0.160296,108,1454,1562
# 5,2011-01-05,1,0,1,0,3,1,1,0.226957,0.22927,0.436957,0.1869,82,1518,1600
# 6,2011-01-06,1,0,1,0,4,1,1,0.204348,0.233209,0.518261,0.0895652,88,1518,1606
# ...

# %% [markdown]
# **Ex 02: Read titanic dataset**
#
#      dbutils.fs.head("dbfs:/FileStore/tables/titanic.csv")
#      dbutils.fs.head("dbfs:/FileStore/tables/titanic.csv", 100)
#      %fs head 'dbfs:/FileStore/tables/titanic.csv'

# %%
dbutils.fs.head("dbfs:/FileStore/tables/titanic.csv")
# Out:
# Out[3]: 'PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked\n1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/5 21171,7.25,,S\n2,1,1,"Cumings, Mrs. John Bradley (Florence Briggs Thayer)",female,38,1,0,PC 17599,71.2833,C85,C\n3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,STON/O2. 3101282,7.925,,S\n4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May Peel)",female,35,1,0,113803,53.1,C123,S\n5,0,3,"Allen, Mr. William Henry",male,35,0,0,373450,8.05,,S\n6,0,3,"Moran, Mr. James",male,,0,0,330877,8.4583,,Q\n7,0,1,"McCarthy, Mr. Timothy J",male,54,0,0,17463,51.8625,E46,S\n8,0,3,"Palsson, Master. Gosta Leonard",male,2,3,1,349909,21.075,,S\n9,1,3,"Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)",female,27,0,2,347742,11.1333,,S\n10,1,2,"Nasser, Mrs. Nicholas (Adele Achem)",female,14,1,0,237736,30.0708,,C\n11,1,3,"Sandstrom, Miss. Marguerite Rut",female,4,1,1,PP 9549,16.7,G6,S\n12,1,1,"Bonnell, Miss. Elizabeth",female,58,0,0,113783,26.55,C103,S\n13,0,3,"Saundercock, Mr. Willi
# ...

# %%
dbutils.fs.head("dbfs:/FileStore/tables/titanic.csv", 200)
# Out:
# [Truncated to first 200 bytes]
# Out[1]: 'PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked\n1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/5 21171,7.25,,S\n2,1,1,"Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
# %fs head 'dbfs:/FileStore/tables/titanic.csv'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 1,0,3,&quot;Braund, Mr. Owen Harris&quot;,male,22,1,0,A/5 21171,7.25,,S
# 2,1,1,&quot;Cumings, Mrs. John Bradley (Florence Briggs Thayer)&quot;,female,38,1,0,PC 17599,71.2833,C85,C
# 3,1,3,&quot;Heikkinen, Miss. Laina&quot;,female,26,0,0,STON/O2. 3101282,7.925,,S
# 4,1,1,&quot;Futrelle, Mrs. Jacques Heath (Lily May Peel)&quot;,female,35,1,0,113803,53.1,C123,S
# 5,0,3,&quot;Allen, Mr. William Henry&quot;,male,35,0,0,373450,8.05,,S
# 6,0,3,&quot;Moran, Mr. James&quot;,male,,0,0,330877,8.4583,,Q
# ...

# %% [markdown]
# ### **3) Format: JSON**

# %% [markdown]
#      dbutils.fs.head("/FileStore/tables/singleline-5.json")
#      dbutils.fs.head("/FileStore/tables/singleline-5.json", 50)
#      %fs head '/FileStore/tables/singleline-5.json'

# %%
dbutils.fs.head("/FileStore/tables/singleline-5.json")
# Out:
# Out[6]: '{"source":"catalog", "description":"bravia", "input_timestamp":1124256609, "last_update_timestamp":1524256609, "country":"IND", "user":"Hari"}\r\n{"source":"SAP", "description":"sony", "input_timestamp":1224256609, "last_update_timestamp":1424256609, "country":"US", "user":"Rajesh"}\r\n{"source":"ADLS", "description":"bse", "input_timestamp":1324256609, "last_update_timestamp":1524256609, "country":"CANADA", "user":"Lokesh"}\r\n{"source":"Blob", "description":"exchange", "input_timestamp":1424256609, "last_update_timestamp":1724256609, "country":"US", "user":"Sharath"}\r\n{"source":"SQL", "description":"Stock", "input_timestamp":1524256609, "last_update_timestamp":1664256609, "country":"SWEDEN", "user":"Sheetal"}\r\n{"source":"datawarehouse", "description":"azure", "input_timestamp":1624256609, "last_update_timestamp":1874256609, "country":"UK", "user":"Raj"}\r\n{"source":"oracle", "description":"ADF", "input_timestamp":1779256609, "last_update_timestamp":188256609, "country
# ...

# %%
dbutils.fs.head("/FileStore/tables/singleline-5.json", 43)
# Out:
# [Truncated to first 43 bytes]
# Out[9]: '{"source":"catalog", "description":"bravia"'

# %%
# %fs head '/FileStore/tables/singleline-5.json'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&quot;source&quot;:&quot;catalog&quot;, &quot;description&quot;:&quot;bravia&quot;, &quot;input_timestamp&quot;:1124256609, &quot;last_update_timestamp&quot;:1524256609, &quot;country&quot;:&quot;IND&quot;, &quot;user&quot;:&quot;Hari&quot;}
# {&quot;source&quot;:&quot;SAP&quot;, &quot;description&quot;:&quot;sony&quot;, &quot;input_timestamp&quot;:1224256609, &quot;last_update_timestamp&quot;:1424256609, &quot;country&quot;:&quot;US&quot;, &quot;user&quot;:&quot;Rajesh&quot;}
# ...

# %%
# %fs head 'dbfs:/FileStore/tables/multiline.json'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[
#   {
#     &quot;source&quot;: &quot;catalog&quot;,
#     &quot;description&quot;: &quot;bravia&quot;,
#     &quot;input_timestamp&quot;: 1124256609,
#     &quot;last_update_timestamp&quot;: 1524256609,
#     &quot;country&quot;: &quot;IND&quot;,
#     &quot;user&quot;: &quot;Hari&quot;
#   },
#   {
#     &quot;source&quot;: &quot;SAP&quot;,
#     &quot;description&quot;: &quot;sony&quot;,
#     &quot;input_timestamp&quot;: 1224256609,
#     &quot;last_update_timestamp&quot;: 1424256609,
#     &quot;country&quot;: &quot;US&quot;,
#     &quot;user&quot;: &quot;Rajesh&quot;
#   },
#   {
# ...

# %% [markdown]
# ### **4) Format: txt**

# %% [markdown]
#      dbutils.fs.head("dbfs:/FileStore/tables/cast_data.txt")
#      dbutils.fs.head("dbfs:/FileStore/tables/cast_data.txt", 50)
#      %fs head 'dbfs:/FileStore/tables/posexplode.txt'

# %%
dbutils.fs.head("dbfs:/FileStore/tables/posexplode.txt")
# Out:
# Out[13]: 'S.No|EmpName|Dept|Technology|Age|Year\r\n1|Sundar|Azure|ADB, ADF, PySpark, SQL|30|2022\r\n2|Sheetal|Azure|None, ADF, PySpark, SQL|35|2023\r\n3|Amar|Azure|ADB, None, PySpark|40|2021\r\n4|Rakesh|Azure|ADB, ADF|33|2023\r\n5|Royal|Azure|ADB, None|35|2022\r\n6|Swapnil|AWS||38|2002'

# %%
dbutils.fs.head("dbfs:/FileStore/tables/posexplode.txt", 50)
# Out:
# [Truncated to first 50 bytes]
# Out[3]: 'S.No|EmpName|Dept|Technology|Age|Year\r\n1|Sundar|Az'

# %%
# %fs head 'dbfs:/FileStore/tables/posexplode.txt'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">S.No|EmpName|Dept|Technology|Age|Year
# 1|Sundar|Azure|ADB, ADF, PySpark, SQL|30|2022
# 2|Sheetal|Azure|None, ADF, PySpark, SQL|35|2023
# 3|Amar|Azure|ADB, None, PySpark|40|2021
# 4|Rakesh|Azure|ADB, ADF|33|2023
# 5|Royal|Azure|ADB, None|35|2022
# 6|Swapnil|AWS||38|2002
# </div>
