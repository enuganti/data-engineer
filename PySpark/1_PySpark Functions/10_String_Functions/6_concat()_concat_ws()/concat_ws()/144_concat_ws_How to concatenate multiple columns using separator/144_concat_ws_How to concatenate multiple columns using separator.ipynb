# %% [markdown]
# #### concat_ws
#
# - used to concatenate multiple input **string columns** into a **single string column**, using a specified **separator**.
# - The **ws** stands for **with separator**.
# - Concatenates `multiple columns` with a **separator**.
# - **Skips NULL** values automatically.

# %% [markdown]
# **Null Handling:**
# - Unlike the basic concat function, `concat_ws` **ignores NULL values** in the `input columns`, meaning `no separator` is added for `missing values`, which helps `avoid entire rows becoming NULL`.

# %% [markdown]
# ##### Syntax
#
#      concat_ws(sep, *cols)
#
# **sep:**
# - A string literal for the `separator` (e.g., **",", " - "**).
#
# ***cols:**
# - The `columns` you want to `concatenate`.
# - This can be specified as `individual column objects` or dynamically using a `list of column names` with the `asterisk (*) to unpack` them.

# %% [markdown]
# **Topics Covered:**
# - `Combining Multiple String Columns`
# - `concat_ws() with NULL values & empty strings`
# - `Handling empty strings explicitly`
# - `Concatenate numeric and string columns`
# - `Concatenate array column using concat_ws()`
# - `Creating composite key`

# %%
from pyspark.sql.functions import concat_ws, col, lit

# %% [markdown]
# ##### 1) Combining Multiple String Columns

# %%
data = [("A1", "2024", "India", "M", 25000),
        ("A2", "2025", "USA", "F", 35000),
        ("A3", "2023", "UK", "M", 33000),
        ("A4", "2022", "Sweden", "F", 34500),
        ("A5", "2021", "Norway", "M", 25988),
        ("A6", "2020", "Germany", "M", 351250),
        ("A7", "2019", "France", "F", 45981),
        ("A8", "2018", "Spain", "M", 19245),
        ("A9", "2017", "Italy", "M", 32765),
        ("A10", "2016", "China", "F", 12398)]

df_01 = spark.createDataFrame(data, ["id", "year", "country", "gender", "salary"])
display(df_01)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>year</th><th>country</th><th>gender</th><th>salary</th></tr></thead><tbody><tr><td>A1</td><td>2024</td><td>India</td><td>M</td><td>25000</td></tr><tr><td>A2</td><td>2025</td><td>USA</td><td>F</td><td>35000</td></tr><tr><td>A3</td><td>2023</td><td>UK</td><td>M</td><td>33000</td></tr><tr><td>A4</td><td>2022</td><td>Sweden</td><td>F</td><td>34500</td></tr><tr><td>A5</td><td>2021</td><td>Norway</td><td>M</td><td>25988</td></tr><tr><td>A6</td><td>2020</td><td>Germany</td><td>M</td><td>351250</td></tr><tr><td>A7</td><td>2019</td><td>France</td><td>F</td><td>45981</td></tr><tr><td>A8</td><td>2018</td><td>Spain</td><td>M</td><td>19245</td></tr><tr><td>A9</td><td>2017</td><td>Italy</td><td>M</td><td>32765</td></tr><tr><td>A10</td><td>2016</td><td>China</td><td>F</td><td>12398</td></tr></tbody></table></div>

# %%
# Create a new column with a space between each column value
# string columns: "id", "year" & "country"
# string columns: "combined_key_space" & "combined_key_underscore"
df_ws_select = df_01.select("id", "year", "country",
                            concat_ws(" ", "id", "year", "country").alias("combined_key_space"),
                            concat_ws("_", "id", "year", "country").alias("combined_key_underscore"))

display(df_ws_select)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>year</th><th>country</th><th>combined_key_space</th><th>combined_key_underscore</th></tr></thead><tbody><tr><td>A1</td><td>2024</td><td>India</td><td>A1 2024 India</td><td>A1_2024_India</td></tr><tr><td>A2</td><td>2025</td><td>USA</td><td>A2 2025 USA</td><td>A2_2025_USA</td></tr><tr><td>A3</td><td>2023</td><td>UK</td><td>A3 2023 UK</td><td>A3_2023_UK</td></tr><tr><td>A4</td><td>2022</td><td>Sweden</td><td>A4 2022 Sweden</td><td>A4_2022_Sweden</td></tr><tr><td>A5</td><td>2021</td><td>Norway</td><td>A5 2021 Norway</td><td>A5_2021_Norway</td></tr><tr><td>A6</td><td>2020</td><td>Germany</td><td>A6 2020 Germany</td><td>A6_2020_Germany</td></tr><tr><td>A7</td><td>2019</td><td>France</td><td>A7 2019 France</td><td>A7_2019_France</td></tr><tr><td>A8</td><td>2018</td><td>Spain</td><td>A8 2018 Spain</td><td>A8_2018_Spain</td></tr><tr><td>A9</td><td>2017</td><td>Italy</td><td>A9 2017 Italy</td><td>A9_2017_Italy</td></tr><tr><td>A10</td><td>2016</td><td>China</td><td>A10 2016 China</td><td>A10_2016_China</td></tr></tbody></table></div>

# %%
# Create a new column with a space between each column value
# string columns: "id", "year" & "country"
# string columns: "combined_key_space" & "combined_key_underscore"
df_ws_with = df_01.withColumn("combined_key_space", concat_ws(" ", "id", "year", "country")) \
                  .withColumn("combined_key_underscore", concat_ws("_", "id", "year", "country")) \
                  .select("id", "year", "country", "combined_key_space", "combined_key_underscore")

display(df_ws_with)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>year</th><th>country</th><th>combined_key_space</th><th>combined_key_underscore</th></tr></thead><tbody><tr><td>A1</td><td>2024</td><td>India</td><td>A1 2024 India</td><td>A1_2024_India</td></tr><tr><td>A2</td><td>2025</td><td>USA</td><td>A2 2025 USA</td><td>A2_2025_USA</td></tr><tr><td>A3</td><td>2023</td><td>UK</td><td>A3 2023 UK</td><td>A3_2023_UK</td></tr><tr><td>A4</td><td>2022</td><td>Sweden</td><td>A4 2022 Sweden</td><td>A4_2022_Sweden</td></tr><tr><td>A5</td><td>2021</td><td>Norway</td><td>A5 2021 Norway</td><td>A5_2021_Norway</td></tr><tr><td>A6</td><td>2020</td><td>Germany</td><td>A6 2020 Germany</td><td>A6_2020_Germany</td></tr><tr><td>A7</td><td>2019</td><td>France</td><td>A7 2019 France</td><td>A7_2019_France</td></tr><tr><td>A8</td><td>2018</td><td>Spain</td><td>A8 2018 Spain</td><td>A8_2018_Spain</td></tr><tr><td>A9</td><td>2017</td><td>Italy</td><td>A9 2017 Italy</td><td>A9_2017_Italy</td></tr><tr><td>A10</td><td>2016</td><td>China</td><td>A10 2016 China</td><td>A10_2016_China</td></tr></tbody></table></div>

# %%
# Create a new column with a space between each column value
# string columns: "id", "year" & "country"
# string columns: "combined_key_comma"
df_ws_comma = df_01.select("*", concat_ws(", ", "id", "year", "country").alias("combined_key_comma"),
                                lit(col("salary")*2).alias("new_salary"))
                           
display(df_ws_comma)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>year</th><th>country</th><th>gender</th><th>salary</th><th>combined_key_comma</th><th>new_salary</th></tr></thead><tbody><tr><td>A1</td><td>2024</td><td>India</td><td>M</td><td>25000</td><td>A1, 2024, India</td><td>50000</td></tr><tr><td>A2</td><td>2025</td><td>USA</td><td>F</td><td>35000</td><td>A2, 2025, USA</td><td>70000</td></tr><tr><td>A3</td><td>2023</td><td>UK</td><td>M</td><td>33000</td><td>A3, 2023, UK</td><td>66000</td></tr><tr><td>A4</td><td>2022</td><td>Sweden</td><td>F</td><td>34500</td><td>A4, 2022, Sweden</td><td>69000</td></tr><tr><td>A5</td><td>2021</td><td>Norway</td><td>M</td><td>25988</td><td>A5, 2021, Norway</td><td>51976</td></tr><tr><td>A6</td><td>2020</td><td>Germany</td><td>M</td><td>351250</td><td>A6, 2020, Germany</td><td>702500</td></tr><tr><td>A7</td><td>2019</td><td>France</td><td>F</td><td>45981</td><td>A7, 2019, France</td><td>91962</td></tr><tr><td>A8</td><td>2018</td><td>Spain</td><td>M</td><td>19245</td><td>A8, 2018, Spain</td><td>38490</td></tr><tr><td>A9</td><td>2017</td><td>Italy</td><td>M</td><td>32765</td><td>A9, 2017, Italy</td><td>65530</td></tr><tr><td>A10</td><td>2016</td><td>China</td><td>F</td><td>12398</td><td>A10, 2016, China</td><td>24796</td></tr></tbody></table></div>

# %% [markdown]
# ##### 2) concat_ws() with NULL values & empty strings
# - `NULL columns` are **skipped** automatically.

# %%
data = [("A1", "2024", "India"),
        ("A2", None, "USA"),
        ("A3", "2023", None),
        ("A4", "2022", "Sweden"),
        (None, "2021", "Norway"),
        ("A6", "2020", "Germany"),
        ("A7", "2019", None),
        ("", "2018", "Spain"),
        ("A9", None, "Italy"),
        ("A10", "", "China")]

df_null_empty = spark.createDataFrame(data, ["id", "year", "country"])
display(df_null_empty)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>year</th><th>country</th></tr></thead><tbody><tr><td>A1</td><td>2024</td><td>India</td></tr><tr><td>A2</td><td>null</td><td>USA</td></tr><tr><td>A3</td><td>2023</td><td>null</td></tr><tr><td>A4</td><td>2022</td><td>Sweden</td></tr><tr><td>null</td><td>2021</td><td>Norway</td></tr><tr><td>A6</td><td>2020</td><td>Germany</td></tr><tr><td>A7</td><td>2019</td><td>null</td></tr><tr><td></td><td>2018</td><td>Spain</td></tr><tr><td>A9</td><td>null</td><td>Italy</td></tr><tr><td>A10</td><td></td><td>China</td></tr></tbody></table></div>

# %%
df_null_with = df_null_empty.withColumn("combined_key_space", concat_ws(" ", "id", "year", "country")) \
                            .withColumn("combined_key_underscore", concat_ws("_", "id", "year", "country"))

display(df_null_with)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>year</th><th>country</th><th>combined_key_space</th><th>combined_key_underscore</th></tr></thead><tbody><tr><td>A1</td><td>2024</td><td>India</td><td>A1 2024 India</td><td>A1_2024_India</td></tr><tr><td>A2</td><td>null</td><td>USA</td><td>A2 USA</td><td>A2_USA</td></tr><tr><td>A3</td><td>2023</td><td>null</td><td>A3 2023</td><td>A3_2023</td></tr><tr><td>A4</td><td>2022</td><td>Sweden</td><td>A4 2022 Sweden</td><td>A4_2022_Sweden</td></tr><tr><td>null</td><td>2021</td><td>Norway</td><td>2021 Norway</td><td>2021_Norway</td></tr><tr><td>A6</td><td>2020</td><td>Germany</td><td>A6 2020 Germany</td><td>A6_2020_Germany</td></tr><tr><td>A7</td><td>2019</td><td>null</td><td>A7 2019</td><td>A7_2019</td></tr><tr><td></td><td>2018</td><td>Spain</td><td> 2018 Spain</td><td>_2018_Spain</td></tr><tr><td>A9</td><td>null</td><td>Italy</td><td>A9 Italy</td><td>A9_Italy</td></tr><tr><td>A10</td><td></td><td>China</td><td>A10  China</td><td>A10__China</td></tr></tbody></table></div>

# %% [markdown]
# ##### 3) Handling empty strings explicitly
# - concat_ws() `skips NULL`, `not empty strings`

# %%
from pyspark.sql.functions import when

dfNullEmpty = df_null_empty \
    .withColumn("full_name_space", concat_ws(" ", when(col("id") == "", None).otherwise(col("id")),
                                                  when(col("year") == "", None).otherwise(col("year")),
                                                  when(col("country") == "", None).otherwise(col("country")))) \
    .withColumn("full_name_under", concat_ws("_", when(col("id") == "", None).otherwise(col("id")),
                                                  when(col("year") == "", None).otherwise(col("year")),
                                                  when(col("country") == "", None).otherwise(col("country")))) \
    .withColumn("combined_key_underscore", concat_ws("_", "id", "year", "country"))

display(dfNullEmpty)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>year</th><th>country</th><th>full_name_space</th><th>full_name_under</th><th>combined_key_underscore</th></tr></thead><tbody><tr><td>A1</td><td>2024</td><td>India</td><td>A1 2024 India</td><td>A1_2024_India</td><td>A1_2024_India</td></tr><tr><td>A2</td><td>null</td><td>USA</td><td>A2 USA</td><td>A2_USA</td><td>A2_USA</td></tr><tr><td>A3</td><td>2023</td><td>null</td><td>A3 2023</td><td>A3_2023</td><td>A3_2023</td></tr><tr><td>A4</td><td>2022</td><td>Sweden</td><td>A4 2022 Sweden</td><td>A4_2022_Sweden</td><td>A4_2022_Sweden</td></tr><tr><td>null</td><td>2021</td><td>Norway</td><td>2021 Norway</td><td>2021_Norway</td><td>2021_Norway</td></tr><tr><td>A6</td><td>2020</td><td>Germany</td><td>A6 2020 Germany</td><td>A6_2020_Germany</td><td>A6_2020_Germany</td></tr><tr><td>A7</td><td>2019</td><td>null</td><td>A7 2019</td><td>A7_2019</td><td>A7_2019</td></tr><tr><td></td><td>2018</td><td>Spain</td><td>2018 Spain</td><td>2018_Spain</td><td>_2018_Spain</td></tr><tr><td>A9</td><td>null</td><td>Italy</td><td>A9 Italy</td><td>A9_Italy</td><td>A9_Italy</td></tr><tr><td>A10</td><td></td><td>China</td><td>A10 China</td><td>A10_China</td><td>A10__China</td></tr></tbody></table></div>

# %% [markdown]
# ##### 4) Concatenate numeric and string columns
# - `Spark` automatically **casts** `numbers to strings`.

# %%
data = [
    (101, "ADLS", 55000),
    (102, "Airflow", 25000),
    (103, "Bolb", 26700),
    (104, "databricks", 19876),
    (105, "dbt", 32786)
]

df_num_str = spark.createDataFrame(data, ["id", "product", "price"])
display(df_num_str)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>product</th><th>price</th></tr></thead><tbody><tr><td>101</td><td>ADLS</td><td>55000</td></tr><tr><td>102</td><td>Airflow</td><td>25000</td></tr><tr><td>103</td><td>Bolb</td><td>26700</td></tr><tr><td>104</td><td>databricks</td><td>19876</td></tr><tr><td>105</td><td>dbt</td><td>32786</td></tr></tbody></table></div>

# %%
df_numStr = df_num_str \
    .withColumn("product_info_space", concat_ws(" - ", col("id"), col("product"), col("price"))) \
    .withColumn("product_info_underscore", concat_ws("_", col("id"), col("product"), col("price"))) \
    .withColumn("product_info_backslash", concat_ws(" / ", col("id"), col("product"), col("price")))
display(df_numStr)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>product</th><th>price</th><th>product_info_space</th><th>product_info_underscore</th><th>product_info_backslash</th></tr></thead><tbody><tr><td>101</td><td>ADLS</td><td>55000</td><td>101 - ADLS - 55000</td><td>101_ADLS_55000</td><td>101 / ADLS / 55000</td></tr><tr><td>102</td><td>Airflow</td><td>25000</td><td>102 - Airflow - 25000</td><td>102_Airflow_25000</td><td>102 / Airflow / 25000</td></tr><tr><td>103</td><td>Bolb</td><td>26700</td><td>103 - Bolb - 26700</td><td>103_Bolb_26700</td><td>103 / Bolb / 26700</td></tr><tr><td>104</td><td>databricks</td><td>19876</td><td>104 - databricks - 19876</td><td>104_databricks_19876</td><td>104 / databricks / 19876</td></tr><tr><td>105</td><td>dbt</td><td>32786</td><td>105 - dbt - 32786</td><td>105_dbt_32786</td><td>105 / dbt / 32786</td></tr></tbody></table></div>

# %% [markdown]
# ##### 5) Concatenate array column using concat_ws()
# - Very useful when `flattening arrays`.

# %%
data = [
    (1, ["Java", "Python", "Spark"]),
    (2, ["SQL", "Excel"]),
    (3, ["Scala", "Python", "R"]),
    (4, ["SQL", "PySpark", "Java"]),
    (5, ["Airflow", "Devops", "SparkSQL"])
]

df_arry = spark.createDataFrame(data, ["id", "skills"])
display(df_arry)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>skills</th></tr></thead><tbody><tr><td>1</td><td>List(Java, Python, Spark)</td></tr><tr><td>2</td><td>List(SQL, Excel)</td></tr><tr><td>3</td><td>List(Scala, Python, R)</td></tr><tr><td>4</td><td>List(SQL, PySpark, Java)</td></tr><tr><td>5</td><td>List(Airflow, Devops, SparkSQL)</td></tr></tbody></table></div>

# %%
df_arry_conc = df_arry.withColumn("skills_str", concat_ws(", ", "skills"))
display(df_arry_conc)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>skills</th><th>skills_str</th></tr></thead><tbody><tr><td>1</td><td>List(Java, Python, Spark)</td><td>Java, Python, Spark</td></tr><tr><td>2</td><td>List(SQL, Excel)</td><td>SQL, Excel</td></tr><tr><td>3</td><td>List(Scala, Python, R)</td><td>Scala, Python, R</td></tr><tr><td>4</td><td>List(SQL, PySpark, Java)</td><td>SQL, PySpark, Java</td></tr><tr><td>5</td><td>List(Airflow, Devops, SparkSQL)</td><td>Airflow, Devops, SparkSQL</td></tr></tbody></table></div>

# %%
df_arry_conc_01 = df_arry.withColumn("skills_str", concat_ws("", "skills"))
display(df_arry_conc_01)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>skills</th><th>skills_str</th></tr></thead><tbody><tr><td>1</td><td>List(Java, Python, Spark)</td><td>JavaPythonSpark</td></tr><tr><td>2</td><td>List(SQL, Excel)</td><td>SQLExcel</td></tr><tr><td>3</td><td>List(Scala, Python, R)</td><td>ScalaPythonR</td></tr><tr><td>4</td><td>List(SQL, PySpark, Java)</td><td>SQLPySparkJava</td></tr><tr><td>5</td><td>List(Airflow, Devops, SparkSQL)</td><td>AirflowDevopsSparkSQL</td></tr></tbody></table></div>

# %%
# df_arry_conc_02 = df_arry.withColumn("skills_str", concat_ws(" ", "skills"))
df_arry_conc_02 = df_arry.withColumn("skills_str", concat_ws(" / ", "skills"))
display(df_arry_conc_02)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>skills</th><th>skills_str</th></tr></thead><tbody><tr><td>1</td><td>List(Java, Python, Spark)</td><td>Java / Python / Spark</td></tr><tr><td>2</td><td>List(SQL, Excel)</td><td>SQL / Excel</td></tr><tr><td>3</td><td>List(Scala, Python, R)</td><td>Scala / Python / R</td></tr><tr><td>4</td><td>List(SQL, PySpark, Java)</td><td>SQL / PySpark / Java</td></tr><tr><td>5</td><td>List(Airflow, Devops, SparkSQL)</td><td>Airflow / Devops / SparkSQL</td></tr></tbody></table></div>

# %% [markdown]
# ##### 6) Creating composite key

# %%
df_key = spark.read.csv("/Volumes/azureadb/pyspark/collect/Sales_Collect.csv", header=True, inferSchema=True)
display(df_key.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>dept_Id</th><th>SubDept_Id</th><th>Vehicle_Id</th><th>Vehicle_Profile_Id</th><th>Description</th><th>Vehicle_Price_Id</th><th>Vehicle_Showroom_Price</th><th>Vehicle_Showroom_Delta</th><th>Vehicle_Showroom_Payment_Date</th><th>Currency</th><th>Target_Currency</th><th>Average</th><th>Increment</th><th>Target_Simulation_Id</th></tr></thead><tbody><tr><td>257</td><td>257</td><td>1</td><td>1</td><td>0</td><td>Baleno</td><td>6</td><td>72567.98</td><td>5678.01</td><td>2023-02-20</td><td>INR</td><td>INR</td><td>2381.657773</td><td>0.0</td><td>1071</td></tr><tr><td>264</td><td>264</td><td>1</td><td>0</td><td>0</td><td>Engine_Base</td><td>90</td><td>91768.98</td><td>12678.01</td><td>2025-06-30</td><td>INR</td><td>INR</td><td>553.8461539</td><td>0.0</td><td>1063</td></tr><tr><td>265</td><td>265</td><td>1</td><td>0</td><td>0</td><td>Baleno</td><td>83</td><td>8400.123</td><td>1450.01</td><td>2023-12-27</td><td>INR</td><td>INR</td><td>-7199.999999</td><td>0.0</td><td>1065</td></tr><tr><td>266</td><td>266</td><td>1</td><td>0</td><td>0</td><td>Engine_Base</td><td>76</td><td>77345.665</td><td>3456.01</td><td>2024-04-30</td><td>INR</td><td>INR</td><td>7200.0</td><td>0.0</td><td>1063</td></tr><tr><td>267</td><td>267</td><td>1</td><td>0</td><td>0</td><td>Suzuki Swift</td><td>96</td><td>974567.11</td><td>110.01</td><td>2025-12-31</td><td>INR</td><td>INR</td><td>1404.878049</td><td>0.0</td><td>1063</td></tr><tr><td>268</td><td>268</td><td>1</td><td>1</td><td>0</td><td>Suzuki Swift</td><td>48</td><td>49.0</td><td>0.01</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>834.1253</td><td>0.0</td><td>1068</td></tr><tr><td>270</td><td>270</td><td>1</td><td>0</td><td>0</td><td>Wagon R</td><td>76</td><td>77345.665</td><td>3456.01</td><td>2024-03-26</td><td>INR</td><td>INR</td><td>7200.0</td><td>0.0</td><td>1065</td></tr><tr><td>271</td><td>271</td><td>1</td><td>0</td><td>0</td><td>Engine_Base</td><td>34</td><td>35.0</td><td>12340.0123</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>1668.2506</td><td>0.0</td><td>1068</td></tr><tr><td>272</td><td>272</td><td>1</td><td>1</td><td>0</td><td>Creta</td><td>29</td><td>30.0</td><td>12340.0123</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>-2383.215143</td><td>0.0</td><td>1071</td></tr><tr><td>277</td><td>277</td><td>1</td><td>0</td><td>0</td><td>Brezza</td><td>73</td><td>74567.34567</td><td>3456.01</td><td>2023-12-28</td><td>INR</td><td>INR</td><td>7440.0</td><td>0.0</td><td>1065</td></tr><tr><td>285</td><td>285</td><td>1</td><td>0</td><td>0</td><td>Ertiga</td><td>83</td><td>8400.123</td><td>1450.01</td><td>2024-11-29</td><td>INR</td><td>INR</td><td>2520.0</td><td>0.0</td><td>1063</td></tr><tr><td>292</td><td>292</td><td>1</td><td>1</td><td>1</td><td>Grand Vitara</td><td>7</td><td>230.9960486</td><td>1289.0001</td><td>2023-06-20</td><td>INR</td><td>INR</td><td>-1013501.197</td><td>424612.4066</td><td>1068</td></tr><tr><td>293</td><td>293</td><td>1</td><td>0</td><td>0</td><td>Verna</td><td>81</td><td>82123.0</td><td>1450.01</td><td>2023-12-27</td><td>INR</td><td>INR</td><td>300.0</td><td>0.0</td><td>1065</td></tr><tr><td>295</td><td>295</td><td>1</td><td>0</td><td>1</td><td>Grand Vitara</td><td>9</td><td>2120.994668</td><td>1289.0001</td><td>2024-03-20</td><td>INR</td><td>INR</td><td>1082123.228</td><td>-889778.7891</td><td>1068</td></tr><tr><td>298</td><td>298</td><td>1</td><td>0</td><td>0</td><td>Engine_Base</td><td>28</td><td>29.0</td><td>12340.0123</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>1668.2506</td><td>0.0</td><td>1068</td></tr><tr><td>307</td><td>307</td><td>1</td><td>0</td><td>0</td><td>Engine_Base</td><td>64</td><td>65.0</td><td>0.01</td><td>2023-05-22</td><td>INR</td><td>INR</td><td>50155.411</td><td>0.0</td><td>1068</td></tr><tr><td>309</td><td>309</td><td>1</td><td>0</td><td>0</td><td>Engine_Base</td><td>47</td><td>48.0</td><td>0.01</td><td>2023-03-20</td><t ...

# %% [markdown]
# **Method 01**

# %%
df_with_id = df_key.select(
    "*",
    concat_ws(
        "_",
        col("Id"),
        col("dept_Id"),
        col("SubDept_Id"),
        col("Vehicle_Id"),
        col("Vehicle_Profile_Id"),
        col("Vehicle_Price_Id")
    ).cast("string").alias("surrogate_key")
)

df_with_id.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>dept_Id</th><th>SubDept_Id</th><th>Vehicle_Id</th><th>Vehicle_Profile_Id</th><th>Description</th><th>Vehicle_Price_Id</th><th>Vehicle_Showroom_Price</th><th>Vehicle_Showroom_Delta</th><th>Vehicle_Showroom_Payment_Date</th><th>Currency</th><th>Target_Currency</th><th>Average</th><th>Increment</th><th>Target_Simulation_Id</th><th>surrogate_key</th></tr></thead><tbody><tr><td>257</td><td>257</td><td>1</td><td>1</td><td>0</td><td>Baleno</td><td>6</td><td>72567.98</td><td>5678.01</td><td>2023-02-20</td><td>INR</td><td>INR</td><td>2381.657773</td><td>0.0</td><td>1071</td><td>257_257_1_1_0_6</td></tr><tr><td>264</td><td>264</td><td>1</td><td>0</td><td>0</td><td>Engine_Base</td><td>90</td><td>91768.98</td><td>12678.01</td><td>2025-06-30</td><td>INR</td><td>INR</td><td>553.8461539</td><td>0.0</td><td>1063</td><td>264_264_1_0_0_90</td></tr><tr><td>265</td><td>265</td><td>1</td><td>0</td><td>0</td><td>Baleno</td><td>83</td><td>8400.123</td><td>1450.01</td><td>2023-12-27</td><td>INR</td><td>INR</td><td>-7199.999999</td><td>0.0</td><td>1065</td><td>265_265_1_0_0_83</td></tr><tr><td>266</td><td>266</td><td>1</td><td>0</td><td>0</td><td>Engine_Base</td><td>76</td><td>77345.665</td><td>3456.01</td><td>2024-04-30</td><td>INR</td><td>INR</td><td>7200.0</td><td>0.0</td><td>1063</td><td>266_266_1_0_0_76</td></tr><tr><td>267</td><td>267</td><td>1</td><td>0</td><td>0</td><td>Suzuki Swift</td><td>96</td><td>974567.11</td><td>110.01</td><td>2025-12-31</td><td>INR</td><td>INR</td><td>1404.878049</td><td>0.0</td><td>1063</td><td>267_267_1_0_0_96</td></tr><tr><td>268</td><td>268</td><td>1</td><td>1</td><td>0</td><td>Suzuki Swift</td><td>48</td><td>49.0</td><td>0.01</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>834.1253</td><td>0.0</td><td>1068</td><td>268_268_1_1_0_48</td></tr><tr><td>270</td><td>270</td><td>1</td><td>0</td><td>0</td><td>Wagon R</td><td>76</td><td>77345.665</td><td>3456.01</td><td>2024-03-26</td><td>INR</td><td>INR</td><td>7200.0</td><td>0.0</td><td>1065</td><td>270_270_1_0_0_76</td></tr><tr><td>271</td><td>271</td><td>1</td><td>0</td><td>0</td><td>Engine_Base</td><td>34</td><td>35.0</td><td>12340.0123</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>1668.2506</td><td>0.0</td><td>1068</td><td>271_271_1_0_0_34</td></tr><tr><td>272</td><td>272</td><td>1</td><td>1</td><td>0</td><td>Creta</td><td>29</td><td>30.0</td><td>12340.0123</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>-2383.215143</td><td>0.0</td><td>1071</td><td>272_272_1_1_0_29</td></tr><tr><td>277</td><td>277</td><td>1</td><td>0</td><td>0</td><td>Brezza</td><td>73</td><td>74567.34567</td><td>3456.01</td><td>2023-12-28</td><td>INR</td><td>INR</td><td>7440.0</td><td>0.0</td><td>1065</td><td>277_277_1_0_0_73</td></tr><tr><td>285</td><td>285</td><td>1</td><td>0</td><td>0</td><td>Ertiga</td><td>83</td><td>8400.123</td><td>1450.01</td><td>2024-11-29</td><td>INR</td><td>INR</td><td>2520.0</td><td>0.0</td><td>1063</td><td>285_285_1_0_0_83</td></tr><tr><td>292</td><td>292</td><td>1</td><td>1</td><td>1</td><td>Grand Vitara</td><td>7</td><td>230.9960486</td><td>1289.0001</td><td>2023-06-20</td><td>INR</td><td>INR</td><td>-1013501.197</td><td>424612.4066</td><td>1068</td><td>292_292_1_1_1_7</td></tr><tr><td>293</td><td>293</td><td>1</td><td>0</td><td>0</td><td>Verna</td><td>81</td><td>82123.0</td><td>1450.01</td><td>2023-12-27</td><td>INR</td><td>INR</td><td>300.0</td><td>0.0</td><td>1065</td><td>293_293_1_0_0_81</td></tr><tr><td>295</td><td>295</td><td>1</td><td>0</td><td>1</td><td>Grand Vitara</td><td>9</td><td>2120.994668</td><td>1289.0001</td><td>2024-03-20</td><td>INR</td><td>INR</td><td>1082123.228</td><td>-889778.7891</td><td>1068</td><td>295_295_1_0_1_9</td></tr><tr><td>298</td><td>298</td><td>1</td><td>0</td><td>0</td><td>Engine_Base</td><td>28</td><td>29.0</td><td>12340.0123</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>1668.2506</td><td ...

# %% [markdown]
# **Method 02**

# %%
from pyspark.sql import functions as F

# %%
primary_cols_mapping = ["Id", "dept_Id", "SubDept_Id", "Vehicle_Id", "Vehicle_Profile_Id", "Vehicle_Price_Id"]

# %%
final_df = (
    df_with_id.select(
        concat_ws("_", *primary_cols_mapping).alias("surrogate_key"),
        *[col(c) for c in df_with_id.columns]
    )
    .distinct()
)

display(final_df.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>surrogate_key</th><th>Id</th><th>dept_Id</th><th>SubDept_Id</th><th>Vehicle_Id</th><th>Vehicle_Profile_Id</th><th>Description</th><th>Vehicle_Price_Id</th><th>Vehicle_Showroom_Price</th><th>Vehicle_Showroom_Delta</th><th>Vehicle_Showroom_Payment_Date</th><th>Currency</th><th>Target_Currency</th><th>Average</th><th>Increment</th><th>Target_Simulation_Id</th><th>surrogate_key</th></tr></thead><tbody><tr><td>342_342_1_1_0_7</td><td>342</td><td>342</td><td>1</td><td>1</td><td>0</td><td>Grand Vitara</td><td>7</td><td>56432.60486</td><td>1289.0001</td><td>2023-05-19</td><td>INR</td><td>INR</td><td>1118619.911</td><td>-268694.1996</td><td>1071</td><td>342_342_1_1_0_7</td></tr><tr><td>357_357_1_2_0_52</td><td>357</td><td>357</td><td>1</td><td>2</td><td>0</td><td>Seltos</td><td>52</td><td>53.0</td><td>134560.01</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>-99.30063095</td><td>0.0</td><td>1071</td><td>357_357_1_2_0_52</td></tr><tr><td>453_453_1_0_0_33</td><td>453</td><td>453</td><td>1</td><td>0</td><td>0</td><td>Suzuki Swift</td><td>33</td><td>34.0</td><td>12340.0123</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>-20.33516498</td><td>0.0</td><td>1068</td><td>453_453_1_0_0_33</td></tr><tr><td>372_372_1_1_10_10</td><td>372</td><td>372</td><td>1</td><td>1</td><td>10</td><td>Grand Vitara</td><td>10</td><td>6789900.995</td><td>1289.0001</td><td>2024-12-20</td><td>INR</td><td>INR</td><td>-1.168101254E7</td><td>2.26730559E7</td><td>1071</td><td>372_372_1_1_10_10</td></tr><tr><td>448_448_1_1_1_65</td><td>448</td><td>448</td><td>1</td><td>1</td><td>1</td><td>Engine_Base</td><td>65</td><td>66345.789</td><td>45678.01</td><td>2023-06-20</td><td>INR</td><td>INR</td><td>-40521.40582</td><td>0.0</td><td>1068</td><td>448_448_1_1_1_65</td></tr><tr><td>481_481_1_0_9_82</td><td>481</td><td>481</td><td>1</td><td>0</td><td>9</td><td>Engine_Base</td><td>82</td><td>83345.1234</td><td>1450.01</td><td>2024-11-20</td><td>INR</td><td>INR</td><td>-40419.26229</td><td>0.0</td><td>1068</td><td>481_481_1_0_9_82</td></tr><tr><td>481_481_1_0_3_10</td><td>481</td><td>481</td><td>1</td><td>0</td><td>3</td><td>Grand Vitara</td><td>10</td><td>6789900.995</td><td>1289.0001</td><td>2024-05-20</td><td>INR</td><td>INR</td><td>2246830.56</td><td>-1671560.202</td><td>1068</td><td>481_481_1_0_3_10</td></tr><tr><td>489_489_1_1_1_65</td><td>489</td><td>489</td><td>1</td><td>1</td><td>1</td><td>EXAUST_SYSTEM</td><td>65</td><td>66345.789</td><td>45678.01</td><td>2023-06-20</td><td>INR</td><td>INR</td><td>1236230.737</td><td>2.9802E-4</td><td>1071</td><td>489_489_1_1_1_65</td></tr><tr><td>466_466_1_0_0_28</td><td>466</td><td>466</td><td>1</td><td>0</td><td>0</td><td>Suzuki Swift</td><td>28</td><td>29.0</td><td>12340.0123</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>104.2472325</td><td>0.0</td><td>1068</td><td>466_466_1_0_0_28</td></tr><tr><td>310_310_1_0_5_8</td><td>310</td><td>310</td><td>1</td><td>0</td><td>5</td><td>Grand Vitara</td><td>8</td><td>3894560.999</td><td>1289.0001</td><td>2023-08-21</td><td>INR</td><td>INR</td><td>-1156473.99</td><td>441708.8814</td><td>1068</td><td>310_310_1_0_5_8</td></tr><tr><td>477_477_1_0_5_8</td><td>477</td><td>477</td><td>1</td><td>0</td><td>5</td><td>Grand Vitara</td><td>8</td><td>3894560.999</td><td>1289.0001</td><td>2023-08-21</td><td>INR</td><td>INR</td><td>-1035510.55</td><td>395507.5517</td><td>1068</td><td>477_477_1_0_5_8</td></tr><tr><td>295_295_1_0_11_84</td><td>295</td><td>295</td><td>1</td><td>0</td><td>11</td><td>Engine_Base</td><td>84</td><td>853456.765</td><td>12678.01</td><td>2025-01-20</td><td>INR</td><td>INR</td><td>-2468.062612</td><td>0.0</td><td>1068</td><td>295_295_1_0_11_84</td></tr><tr><td>268_268_1_1_0_49</td><td>268</td><td>268</td><td>1</td><td>1</td><td>0</td><td>Suzuki Swift</td><td>49</td><td>50.0</td><td>134560.01</td><td>2023-03-20</td><td>INR</td><td>INR</td><td>834.1253</td><td>0.0 ...

# %% [markdown]
# ##### Summary of use cases
#
# | Use Case        | Example                     |
# | --------------- | --------------------------- |
# | Merge columns   | `First + Last Name`         |
# | Create IDs      | `Combine ID`, year, country |
# | Dynamic lists   | `array(*cols)`              |
# | `Ignore nulls`  | `Automatically handled`     |
# | `ETL keys`      | **PRODUCT_KEY, HEADER_ID**  |

# %% [markdown]
# **Key Points to Remember**
#
# - `Separator is mandatory`
# - `Skips NULL values, not empty strings`
# - Works with `strings, numbers, arrays`
# - Commonly used for:
#   - `Full name creation`
#   - `Composite keys`
#   - `Address formatting`
#   - `Flattening array columns`
