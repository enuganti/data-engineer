# %% [markdown]
# ##### How to Cast multiple columns of a DataFrame to given types?
#
# - why filtering with `if date_format`?

# %% [markdown]
# ##### 1) with `if date_format`:

# %%
import pyspark.sql.functions as F
from pyspark.sql.functions import col
from pyspark.sql.types import LongType, DoubleType

# %%
# All columns are in string type
# All rows of timestamp are in default format

# Sample data
data = [
    ("Albert", "25", "6.5", "2025-08-25T15:30:00.000+00:00"),
    ("Baskar", "30", "1.5", "2024-12-31T08:45:15.000+00:00"),
    ("Chetan", "27", "2.7", "2023-01-15T20:00:00.000+00:00"),
    ("Dravid", "26", "4.9", "2024-05-22T15:40:55.000+00:00"),
    ("Nishant", "32", "8.2", "2020-10-31T06:45:45.000+00:00"),
    ("David", "29", "5.1", "2021-08-28T20:15:55.000+00:00"),
    ("Mohan", "33", "9.3", "2019-09-29T19:35:55.000+00:00"),
    ("Niroop", "35", "6.7", "2024-05-22T08:45:25.000+00:00"),
    ("Pushpa", "23", "4.0", "2023-09-25T20:00:00.000+00:00")
]

# Define schema
columns = ["name", "age", "distance", "last_login"]

df_frmt = spark.createDataFrame(data, columns)
display(df_frmt)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>age</th><th>distance</th><th>last_login</th></tr></thead><tbody><tr><td>Albert</td><td>25</td><td>6.5</td><td>2025-08-25T15:30:00.000+00:00</td></tr><tr><td>Baskar</td><td>30</td><td>1.5</td><td>2024-12-31T08:45:15.000+00:00</td></tr><tr><td>Chetan</td><td>27</td><td>2.7</td><td>2023-01-15T20:00:00.000+00:00</td></tr><tr><td>Dravid</td><td>26</td><td>4.9</td><td>2024-05-22T15:40:55.000+00:00</td></tr><tr><td>Nishant</td><td>32</td><td>8.2</td><td>2020-10-31T06:45:45.000+00:00</td></tr><tr><td>David</td><td>29</td><td>5.1</td><td>2021-08-28T20:15:55.000+00:00</td></tr><tr><td>Mohan</td><td>33</td><td>9.3</td><td>2019-09-29T19:35:55.000+00:00</td></tr><tr><td>Niroop</td><td>35</td><td>6.7</td><td>2024-05-22T08:45:25.000+00:00</td></tr><tr><td>Pushpa</td><td>23</td><td>4.0</td><td>2023-09-25T20:00:00.000+00:00</td></tr></tbody></table></div>

# %%
col_type_map_none = {
    "name": "string",
    "age": "int",
    "last_login": "timestamp"
}

# %%
def convert_columns_date_format(df, col_name, date_format=None):
    """
    How to Cast multiple columns of a DataFrame to given types?

    Args:
        df (DataFrame): Input DataFrame
        col_type_map (dict): Dictionary of { "column_name": "target_dataType" }
                             target_dataType can be: string, int, double, boolean, date, timestamp
        date_format (str, optional): Custom format for date/timestamp parsing

    Returns:
        DataFrame: Transformed DataFrame with casted columns
    """
    for column_name, target_dataType in col_type_map_none.items():
        target_dataType = target_dataType.lower()

        if target_dataType == "timestamp":
            if date_format:
                df = df.withColumn(column_name, F.to_timestamp(F.col(column_name), date_format))
    return df

# %%
# Convert last_login column to timestamp with default format

df_conv_default = convert_columns_date_format(df_frmt, "last_login", "yyyy-MM-dd'T'HH:mm:ss.SSSXXX")
display(df_conv_default)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>age</th><th>distance</th><th>last_login</th></tr></thead><tbody><tr><td>Albert</td><td>25</td><td>6.5</td><td>2025-08-25T15:30:00.000Z</td></tr><tr><td>Baskar</td><td>30</td><td>1.5</td><td>2024-12-31T08:45:15.000Z</td></tr><tr><td>Chetan</td><td>27</td><td>2.7</td><td>2023-01-15T20:00:00.000Z</td></tr><tr><td>Dravid</td><td>26</td><td>4.9</td><td>2024-05-22T15:40:55.000Z</td></tr><tr><td>Nishant</td><td>32</td><td>8.2</td><td>2020-10-31T06:45:45.000Z</td></tr><tr><td>David</td><td>29</td><td>5.1</td><td>2021-08-28T20:15:55.000Z</td></tr><tr><td>Mohan</td><td>33</td><td>9.3</td><td>2019-09-29T19:35:55.000Z</td></tr><tr><td>Niroop</td><td>35</td><td>6.7</td><td>2024-05-22T08:45:25.000Z</td></tr><tr><td>Pushpa</td><td>23</td><td>4.0</td><td>2023-09-25T20:00:00.000Z</td></tr></tbody></table></div>

# %%
# skip date_format, last_login column is in default format
df_conv_none = convert_columns_date_format(df_frmt, "last_login")
display(df_conv_none)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>age</th><th>distance</th><th>last_login</th></tr></thead><tbody><tr><td>Albert</td><td>25</td><td>6.5</td><td>2025-08-25T15:30:00.000+00:00</td></tr><tr><td>Baskar</td><td>30</td><td>1.5</td><td>2024-12-31T08:45:15.000+00:00</td></tr><tr><td>Chetan</td><td>27</td><td>2.7</td><td>2023-01-15T20:00:00.000+00:00</td></tr><tr><td>Dravid</td><td>26</td><td>4.9</td><td>2024-05-22T15:40:55.000+00:00</td></tr><tr><td>Nishant</td><td>32</td><td>8.2</td><td>2020-10-31T06:45:45.000+00:00</td></tr><tr><td>David</td><td>29</td><td>5.1</td><td>2021-08-28T20:15:55.000+00:00</td></tr><tr><td>Mohan</td><td>33</td><td>9.3</td><td>2019-09-29T19:35:55.000+00:00</td></tr><tr><td>Niroop</td><td>35</td><td>6.7</td><td>2024-05-22T08:45:25.000+00:00</td></tr><tr><td>Pushpa</td><td>23</td><td>4.0</td><td>2023-09-25T20:00:00.000+00:00</td></tr></tbody></table></div>

# %% [markdown]
# - The function only converts to **timestamp** if a **date_format** is provided.
# - Without **date_format**, the conversion is **skipped** in the function logic.

# %% [markdown]
#      if date_format:
#          df = df.withColumn(column_name, F.to_timestamp(F.col(column_name), date_format))
#
# - **if date_format:** checks if the user has **passed a value** for **date_format**.
# - In Python, below are treated as **Falsey**, so the **block only runs** if you provided a real string like **"yyyy-MM-dd"**.
#   - **None**
#   - **"" (empty string)**
#   - **False**

# %% [markdown]
# ##### 2) without `if date_format`:

# %%
def convert_columns_wo_date_format(df, col_name, date_format=None):
    for column_name, target_dataType in col_type_map_none.items():
        target_dataType = target_dataType.lower()

        if target_dataType == "timestamp":
            df = df.withColumn(column_name, F.to_timestamp(F.col(column_name), date_format))
    return df

# %%
df_conv_wo_date_format = convert_columns_wo_date_format(df_frmt, "last_login")
display(df_conv_wo_date_format)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>age</th><th>distance</th><th>last_login</th></tr></thead><tbody><tr><td>Albert</td><td>25</td><td>6.5</td><td>2025-08-25T15:30:00.000Z</td></tr><tr><td>Baskar</td><td>30</td><td>1.5</td><td>2024-12-31T08:45:15.000Z</td></tr><tr><td>Chetan</td><td>27</td><td>2.7</td><td>2023-01-15T20:00:00.000Z</td></tr><tr><td>Dravid</td><td>26</td><td>4.9</td><td>2024-05-22T15:40:55.000Z</td></tr><tr><td>Nishant</td><td>32</td><td>8.2</td><td>2020-10-31T06:45:45.000Z</td></tr><tr><td>David</td><td>29</td><td>5.1</td><td>2021-08-28T20:15:55.000Z</td></tr><tr><td>Mohan</td><td>33</td><td>9.3</td><td>2019-09-29T19:35:55.000Z</td></tr><tr><td>Niroop</td><td>35</td><td>6.7</td><td>2024-05-22T08:45:25.000Z</td></tr><tr><td>Pushpa</td><td>23</td><td>4.0</td><td>2023-09-25T20:00:00.000Z</td></tr></tbody></table></div>

# %% [markdown]
# - The column **'last_login'** is converted as **timestamp** because in **convert_columns_wo_date_format**, **F.to_date(F.col(column_name), date_format)** is called **regardless of whether date_format is None**.
# - When **date_format is None**, **F.to_date** uses the default format **yyyy-MM-dd** and tries to parse the string.

# %% [markdown]
# ##### 3) All data types

# %%
# Sample data
data = [
    ("Albert", "25", "1500.55", "6.5", "2025-08-25T15:30:00.000+00:00"),
    ("Baskar", "30", "999.99", "1.5", "2024-12-31T08:45:15.000+00:00"),
    ("Chetan", "27", "1503.55", "2.7", "2023-01-15T20:00:00.000+00:00"),
    ("Dravid", "26", "998.99", "4.9", "2024-05-22T15:40:55.000+00:00"),
    ("Nishant", "32", "789.87", "8.2", "2020-10-31T06:45:45.000+00:00"),
    ("David", "29", "159.09", "5.1", "2021-08-28T20:15:55.000+00:00"),
    ("Mohan", "33", "346.23", "9.3", "2019-09-29T19:35:55.000+00:00"),
    ("Niroop", "35", "123.00", "6.7", "2024-05-22T08:45:25.000+00:00"),
    ("Pushpa", "23", "698.11", "4.0", "2023-09-25T20:00:00.000+00:00")
]

# Define schema
columns = ["name", "age", "amount", "distance", "last_login"]

df = spark.createDataFrame(data, columns)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>age</th><th>amount</th><th>distance</th><th>last_login</th></tr></thead><tbody><tr><td>Albert</td><td>25</td><td>1500.55</td><td>6.5</td><td>2025-08-25T15:30:00.000+00:00</td></tr><tr><td>Baskar</td><td>30</td><td>999.99</td><td>1.5</td><td>2024-12-31T08:45:15.000+00:00</td></tr><tr><td>Chetan</td><td>27</td><td>1503.55</td><td>2.7</td><td>2023-01-15T20:00:00.000+00:00</td></tr><tr><td>Dravid</td><td>26</td><td>998.99</td><td>4.9</td><td>2024-05-22T15:40:55.000+00:00</td></tr><tr><td>Nishant</td><td>32</td><td>789.87</td><td>8.2</td><td>2020-10-31T06:45:45.000+00:00</td></tr><tr><td>David</td><td>29</td><td>159.09</td><td>5.1</td><td>2021-08-28T20:15:55.000+00:00</td></tr><tr><td>Mohan</td><td>33</td><td>346.23</td><td>9.3</td><td>2019-09-29T19:35:55.000+00:00</td></tr><tr><td>Niroop</td><td>35</td><td>123.00</td><td>6.7</td><td>2024-05-22T08:45:25.000+00:00</td></tr><tr><td>Pushpa</td><td>23</td><td>698.11</td><td>4.0</td><td>2023-09-25T20:00:00.000+00:00</td></tr></tbody></table></div>

# %%
def convert_columns_date_format_all(df, col_type_map, date_format=None):
    for col_name, target_type in col_type_map.items():
        target_type = target_type.lower()

        if target_type == "timestamp":
            if date_format:
                df = df.withColumn(col_name, F.to_timestamp(F.col(col_name), date_format))
            else:
                df = df.withColumn(col_name, F.to_timestamp(F.col(col_name)))
        elif target_type == "int":
            df = df.withColumn(col_name, F.col(col_name).cast(LongType()))
        elif target_type == "double":
            df = df.withColumn(col_name, F.col(col_name).cast(DoubleType()))
        # elif target_type == "string":
        #     df = df.withColumn(col_name, F.col(col_name).cast("string"))
        else:
            pass
    return df

# %%
col_type_map = {
    "name": "string",
    "age": "int",
    "amount": "double",
    "distance": "double",
    "last_login": "timestamp"
}

# %%
df_convert_columns_date_format_all = convert_columns_date_format_all(df, col_type_map, "yyyy-MM-dd'T'HH:mm:ss.SSSXXX")
display(df_convert_columns_date_format_all)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>age</th><th>amount</th><th>distance</th><th>last_login</th></tr></thead><tbody><tr><td>Albert</td><td>25</td><td>1500.55</td><td>6.5</td><td>2025-08-25T15:30:00.000Z</td></tr><tr><td>Baskar</td><td>30</td><td>999.99</td><td>1.5</td><td>2024-12-31T08:45:15.000Z</td></tr><tr><td>Chetan</td><td>27</td><td>1503.55</td><td>2.7</td><td>2023-01-15T20:00:00.000Z</td></tr><tr><td>Dravid</td><td>26</td><td>998.99</td><td>4.9</td><td>2024-05-22T15:40:55.000Z</td></tr><tr><td>Nishant</td><td>32</td><td>789.87</td><td>8.2</td><td>2020-10-31T06:45:45.000Z</td></tr><tr><td>David</td><td>29</td><td>159.09</td><td>5.1</td><td>2021-08-28T20:15:55.000Z</td></tr><tr><td>Mohan</td><td>33</td><td>346.23</td><td>9.3</td><td>2019-09-29T19:35:55.000Z</td></tr><tr><td>Niroop</td><td>35</td><td>123.0</td><td>6.7</td><td>2024-05-22T08:45:25.000Z</td></tr><tr><td>Pushpa</td><td>23</td><td>698.11</td><td>4.0</td><td>2023-09-25T20:00:00.000Z</td></tr></tbody></table></div>
